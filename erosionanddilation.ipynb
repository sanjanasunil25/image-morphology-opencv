# %%
# Install OpenCV and matplotlib (if not already)
# !pip install opencv-python-headless matplotlib

import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files

# Step 1: Upload image
uploaded = files.upload()

# Get uploaded file name
filename = list(uploaded.keys())[0]

# Step 2: Read image
img = cv2.imread(filename)

# Step 3: Convert to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Step 4: Convert to binary (black & white) using threshold
_, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)

# Step 5: Define kernel
kernel = np.ones((5, 5), np.uint8)

# Step 6: Apply erosion and dilation
erosion = cv2.erode(binary, kernel, iterations=1)
dilation = cv2.dilate(binary, kernel, iterations=1)

# Step 7: Show results
plt.figure(figsize=(12, 4))

plt.subplot(1, 4, 1)
plt.title("Original")
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis("off")

plt.subplot(1, 4, 2)
plt.title("Grayscale")
plt.imshow(gray, cmap="gray")
plt.axis("off")

plt.subplot(1, 4, 3)
plt.title("Erosion")
plt.imshow(erosion, cmap="gray")
plt.axis("off")

plt.subplot(1, 4, 4)
plt.title("Dilation")
plt.imshow(dilation, cmap="gray")
plt.axis("off")

plt.show()
# Out:
# ...
#      <input type="file" id="files-6b1ac1f1-3e88-4f57-ade1-0f1a4c2b3b86" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6b1ac1f1-3e88-4f57-ade1-0f1a4c2b3b86">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Install OpenCV and matplotlib (if not already)
# !pip install opencv-python-headless matplotlib

import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files

# Step 1: Upload image
uploaded = files.upload()

# Get uploaded file name
filename = list(uploaded.keys())[0]

# Step 2: Read image
img = cv2.imread(filename)

# Step 3: Convert to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Step 4: Convert to binary (black & white) using threshold
_, binary = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)

# Step 5: Define kernel
kernel = np.ones((5, 5), np.uint8)

# Step 6: Apply erosion and dilation
erosion = cv2.erode(binary, kernel, iterations=1)
dilation = cv2.dilate(binary, kernel, iterations=1)

# Step 7: Show results
plt.figure(figsize=(12, 4))

plt.subplot(1, 4, 1)
plt.title("Original")
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis("off")

plt.subplot(1, 4, 2)
plt.title("Grayscale")
plt.imshow(gray, cmap="gray")
plt.axis("off")

plt.subplot(1, 4, 3)
plt.title("Erosion")
plt.imshow(erosion, cmap="gray")
plt.axis("off")

plt.subplot(1, 4, 4)
plt.title("Dilation")
plt.imshow(dilation, cmap="gray")
plt.axis("off")

plt.show()
